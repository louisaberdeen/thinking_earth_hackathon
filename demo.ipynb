# %% [markdown]
# # Demo for DOFA
# ### DOFA supports input images with any number of channels using our pre-trained foundation models
# ### The following examples show how to use DOFA for Sentinel-1 (SAR), Sentinel-2, NAIP RGB, Gaofen Multispectral, and Hyperspectral data

# %% [markdown]
# ---

# %% [markdown]
# ### Download the pre-trained weights for DOFA from huggingface

# %%
from huggingface_hub import hf_hub_download
import os

# Option 2: Create a specific directory for models
model_dir = "/content/models"  # Colab's content directory
os.makedirs(model_dir, exist_ok=True)

print(f"Downloading to: {model_dir}")

# Download the file
downloaded_file = hf_hub_download(
    repo_id="XShadow/DOFA",
    filename="DOFA_ViT_base_e100.pth",
    local_dir=model_dir,
    local_dir_use_symlinks=False
)

print(f"File downloaded to: {downloaded_file}")

# Verify the file exists
if os.path.exists(downloaded_file):
    file_size = os.path.getsize(downloaded_file) / (1024 * 1024)  # Size in MB
    print(f"✓ Download successful! File size: {file_size:.2f} MB")
else:
    print("✗ Download failed!")
# Out:
# Downloading to: /content/models
# File downloaded to: /content/models/DOFA_ViT_base_e100.pth
# ✓ Download successful! File size: 426.93 MB

# %%
# !pip install rasterio kornia torchgeo
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.4.3)
# Requirement already satisfied: kornia in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Collecting torchgeo
#   Downloading torchgeo-0.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.8.3)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.2.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.4)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia) (0.1.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia) (25.0)
# Requirement already satisfied: torch>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from kornia) (2.8.0+cu126)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (0.8.1)
# Collecting fiona>=1.8.22 (from torchgeo)
#   Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.2 MB/s eta 0:00:00
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo)
#   Downloading lightly-1.5.22-py3-none-any.whl.metadata (38 kB)
# Collecting lightning!=2.3.*,!=2.5.0,>=2 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading lightning-2.5.5-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (3.10.0)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (2.2.2)
# Requirement already satisfied: pillow>=9.2 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (11.3.0)
# Requirement already satisfied: pyproj>=3.4 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (3.7.2)
# Collecting rtree>=1.0.1 (from torchgeo)
#   Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting segmentation-models-pytorch>=0.5 (from torchgeo)
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: shapely>=1.8.5 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (2.1.1)
# Requirement already satisfied: timm>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (1.0.19)
# Collecting torchmetrics>=1.2 (from torchgeo)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: torchvision>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (0.23.0+cu126)
# Requirement already satisfied: typing-extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from torchgeo) (4.15.0)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo)
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: python_dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.9.0.post0)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.32.4)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (1.17.0)
# Requirement already satisfied: tqdm>=4.44 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (4.67.1)
# Requirement already satisfied: pydantic>=1.10.5 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.11.9)
# Collecting pytorch_lightning>=1.0.4 (from lightly!=1.4.26,>=1.4.5->torchgeo)
#   Downloading pytorch_lightning-2.5.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo) (2.5.0)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo)
#   Downloading aenum-3.1.16-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (6.0.2)
# Requirement already satisfied: fsspec<2027.0,>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting bitsandbytes<1.0,>=0.45.2 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# Collecting jsonargparse<5.0,>=4.39.0 (from jsonargparse[jsonnet,signatures]<5.0,>=4.39.0; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading jsonargparse-4.41.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: omegaconf<3.0,>=2.2.3 in /usr/local/lib/python3.12/dist-packages (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (2.3.0)
# Requirement already satisfied: rich<15.0,>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (13.9.4)
# Collecting tensorboardX<3.0,>=2.2 (from lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->torchgeo) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->torchgeo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->torchgeo) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->torchgeo) (1.4.9)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->torchgeo) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5->torchgeo) (2025.2)
# Requirement already satisfied: huggingface-hub>=0.24 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch>=0.5->torchgeo) (0.35.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from segmentation-models-pytorch>=0.5->torchgeo) (0.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (3.19.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.1->kornia) (3.4.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (3.12.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24->segmentation-models-pytorch>=0.5->torchgeo) (1.1.10)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo) (4.9.3)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[jsonnet,signatures]<5.0,>=4.39.0; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (0.17.0)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[jsonnet,signatures]<5.0,>=4.39.0; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading typeshed_client-2.8.2-py3-none-any.whl.metadata (9.9 kB)
# Collecting jsonnet>=0.21.0 (from jsonargparse[jsonnet,signatures]<5.0,>=4.39.0; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo)
#   Downloading jsonnet-0.21.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (449 bytes)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.5->lightly!=1.4.26,>=1.4.5->torchgeo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.5->lightly!=1.4.26,>=1.4.5->torchgeo) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=1.10.5->lightly!=1.4.26,>=1.4.5->torchgeo) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.0->lightly!=1.4.26,>=1.4.5->torchgeo) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.27.0->lightly!=1.4.26,>=1.4.5->torchgeo) (3.10)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<15.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (2.19.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9.1->kornia) (1.3.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX<3.0,>=2.2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (5.29.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9.1->kornia) (3.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2027.0,>=2022.5.0->lightning!=2.3.*,!=2.5.0,>=2->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (1.20.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<15.0,>=12.3.0->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (0.1.2)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[jsonnet,signatures]<5.0,>=4.39.0; extra == "pytorch-extra"->lightning[pytorch-extra]!=2.3.*,!=2.5.0,>=2->torchgeo) (6.5.2)
# Downloading torchgeo-0.7.1-py3-none-any.whl (605 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.3/605.3 kB 14.3 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 62.3 MB/s eta 0:00:00
# Downloading lightly-1.5.22-py3-none-any.whl (859 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.3/859.3 kB 46.2 MB/s eta 0:00:00
# Downloading lightning-2.5.5-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.5/828.5 kB 46.5 MB/s eta 0:00:00
# Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.6/507.6 kB 36.0 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 13.0 MB/s eta 0:00:00
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 43.2 MB/s eta 0:00:00
# Downloading aenum-3.1.16-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 14.3 MB/s eta 0:00:00
# Downloading bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 8.8 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.4 MB/s eta 0:00:00
# Downloading jsonargparse-4.41.0-py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.5/228.5 kB 17.3 MB/s eta 0:00:00
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading pytorch_lightning-2.5.5-py3-none-any.whl (832 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 51.6 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.1 MB/s eta 0:00:00
# Downloading jsonnet-0.21.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 113.2 MB/s eta 0:00:00
# Downloading typeshed_client-2.8.2-py3-none-any.whl (760 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.5/760.5 kB 48.0 MB/s eta 0:00:00
# Installing collected packages: jsonnet, aenum, typeshed-client, tensorboardX, rtree, lightning-utilities, lightly_utils, jsonargparse, hydra-core, fiona, torchmetrics, bitsandbytes, pytorch_lightning, segmentation-models-pytorch, lightning, lightly, torchgeo
# Successfully installed aenum-3.1.16 bitsandbytes-0.47.0 fiona-1.10.1 hydra-core-1.3.2 jsonargparse-4.41.0 jsonnet-0.21.0 lightly-1.5.22 lightly_utils-0.0.2 lightning-2.5.5 lightning-utilities-0.15.2 pytorch_lightning-2.5.5 rtree-1.4.1 segmentation-models-pytorch-0.5.0 tensorboardX-2.6.4 torchgeo-0.7.1 torchmetrics-1.8.2 typeshed-client-2.8.2

# %%
# Step 1: Data preprocessing (normalization and resize)

import torch
import rasterio
import kornia as K
import numpy as np
# vh,vv
S1_MEAN = [166.36275909, 88.45542715]# / 255.0
S1_STD = [64.83126309, 43.07350145]# /255.0

S2_MEAN = [114.1099739 , 114.81779093, 126.63977424,  84.33539309,
        97.84789168, 103.94461911, 101.435633  ,  72.32804172,
        56.66528851]
S2_STD = [77.84352553, 69.96844919, 67.42465279, 64.57022983, 61.72545487,
       61.34187099, 60.29744676, 47.88519516, 42.55886798]

NAIP_MEAN = [123.675, 116.28, 103.53] # ImageNet stats for now
NAIP_STD = [58.395, 57.12, 57.375] # ImageNet stats for now

Hyper_MEAN = [0.04904891, 0.04734517, 0.04881499, 0.0521312 , 0.05371449,
       0.05431649, 0.05600387, 0.05753566, 0.05837488, 0.06014395,
       0.06120129, 0.06187369, 0.06262351, 0.0640324 , 0.06544493,
       0.06583978, 0.06657578, 0.06818208, 0.06887893, 0.07050433,
       0.0730939 , 0.07500546, 0.07658557, 0.07914317, 0.08149088,
       0.08413605, 0.08584346, 0.0875968 , 0.08949799, 0.09126373,
       0.09284472, 0.09385966, 0.09429929, 0.09644857, 0.09758445,
       0.09888336, 0.1000851 , 0.1012402 , 0.10217949, 0.10292227,
       0.10441044, 0.10482953, 0.10586129, 0.10771345, 0.10875386,
       0.10872938, 0.10955398, 0.11022133, 0.11095442, 0.11202578,
       0.1144143 , 0.11816488, 0.12615164, 0.13405322, 0.14239053,
       0.14940845, 0.15952006, 0.16786492, 0.17470501, 0.17793106,
       0.18344983, 0.1717895 , 0.18624028, 0.18920699, 0.19094643,
       0.19191591, 0.19321348, 0.19543689, 0.19453696, 0.197083  ,
       0.19759373, 0.20008718, 0.20109805, 0.20273463, 0.20447857,
       0.20549563, 0.20768884, 0.20616769, 0.20696713, 0.21603036,
       0.20431315, 0.20028888, 0.21381801, 0.19553433, 0.22010142,
       0.20745818, 0.20469215, 0.20106881, 0.21624712, 0.20217295,
       0.21258003, 0.19276747, 0.19084313, 0.21547508, 0.1990552 ,
       0.2220764 , 0.20010307, 0.22556668, 0.20294108, 0.20432738,
       0.22884114, 0.23084754, 0.23361147, 0.23613915, 0.23835524,
       0.24002708, 0.24240751, 0.24512835, 0.24625339, 0.24729841,
       0.24621868, 0.2335448 , 0.23611045, 0.23486711, 0.22491438,
       0.23376624, 0.23624881, 0.23806269, 0.23892529, 0.24048481,
       0.24448228, 0.24877857, 0.25137802, 0.25356494, 0.25809049,
       0.25776253, 0.19769041, 0.20087005, 0.20429956, 0.20702436,
       0.21026749, 0.21287441, 0.21557267, 0.21920979, 0.22113606,
       0.2227512 , 0.22380759, 0.22556949, 0.22486467, 0.22534442,
       0.22393468, 0.22259283, 0.22103291, 0.21938812, 0.21726496,
       0.15029096, 0.15920778, 0.14992988, 0.1402144 , 0.14215149,
       0.16192129, 0.16663248, 0.16954731, 0.16092901, 0.16268809,
       0.16303404, 0.16922207, 0.16708257, 0.16741623, 0.16829468,
       0.16974312, 0.17043488, 0.17164688, 0.17061502, 0.17135934,
       0.17061249, 0.17054758, 0.17006451, 0.17125258, 0.16988001,
       0.16870924, 0.16756754, 0.1703907 , 0.17044655, 0.16995895,
       0.16583233, 0.16387971, 0.15977418, 0.15813546, 0.15500555,
       0.15475487, 0.1500904 , 0.14842632, 0.14555257, 0.1444372 ,
       0.14345487, 0.1439716 , 0.13948618, 0.13974816, 0.1388893 ,
       0.1425306 , 0.1399015 , 0.14124387, 0.13716652, 0.13908459,
       0.13517979, 0.13579579, 0.12699047, 0.13110322, 0.12600956,
       0.12683088, 0.11266357]

Hyper_STD = [0.05438845, 0.05425398, 0.05519192, 0.05621342, 0.05694766,
       0.05704381, 0.05763639, 0.05804253, 0.05834612, 0.05888857,
       0.05920108, 0.05948167, 0.06002252, 0.06070791, 0.06148699,
       0.06196402, 0.06251209, 0.063477  , 0.06412124, 0.06480832,
       0.06584631, 0.06655134, 0.06710579, 0.06817766, 0.06930595,
       0.07081702, 0.07204193, 0.07329206, 0.07491294, 0.07681551,
       0.07890642, 0.08096196, 0.08243044, 0.08428552, 0.08603505,
       0.08763417, 0.08869326, 0.08985463, 0.09081571, 0.09164355,
       0.09288558, 0.09362094, 0.09377934, 0.09490612, 0.09628371,
       0.09688408, 0.09770997, 0.09843717, 0.099185  , 0.09957288,
       0.10124085, 0.10085674, 0.0999966 , 0.09884673, 0.09924151,
       0.10034673, 0.10382162, 0.10637773, 0.10945914, 0.11091637,
       0.1143651 , 0.11309448, 0.11714786, 0.11771383, 0.11835992,
       0.11911578, 0.11971312, 0.12100819, 0.12134505, 0.12288926,
       0.1223688 , 0.12337272, 0.12378503, 0.1247803 , 0.12574014,
       0.12591301, 0.12706246, 0.12643132, 0.1274808 , 0.12616546,
       0.12669385, 0.12547143, 0.12466624, 0.12086743, 0.1281701 ,
       0.12939227, 0.11918587, 0.1359367 , 0.12719588, 0.13615098,
       0.12415102, 0.12939233, 0.12601028, 0.12531339, 0.12763924,
       0.12921317, 0.12880291, 0.13102435, 0.13017717, 0.13047819,
       0.13304893, 0.13441405, 0.13619871, 0.13785246, 0.13942554,
       0.14062946, 0.14236353, 0.14349961, 0.14351399, 0.14394955,
       0.14339238, 0.13597313, 0.13902099, 0.13897383, 0.13261457,
       0.1377756 , 0.13982825, 0.14176949, 0.14285451, 0.14382317,
       0.14602028, 0.1482343 , 0.15007727, 0.15194561, 0.153546  ,
       0.15312391, 0.14626474, 0.1466966 , 0.14744146, 0.14778844,
       0.14876473, 0.14891526, 0.14976731, 0.15107008, 0.15135105,
       0.15174565, 0.15199847, 0.15274257, 0.15231952, 0.15232084,
       0.1517344 , 0.15127988, 0.15108911, 0.15042051, 0.1496356 ,
       0.13592469, 0.14091663, 0.13328618, 0.11833   , 0.12461805,
       0.13769715, 0.1433956 , 0.14432674, 0.13841473, 0.13815018,
       0.13944786, 0.14269211, 0.14142959, 0.14021556, 0.14112666,
       0.14058631, 0.14122906, 0.14030282, 0.1395203 , 0.13781546,
       0.13659598, 0.13416635, 0.13343848, 0.13207203, 0.13057547,
       0.12746956, 0.12577166, 0.12779064, 0.12974892, 0.12913598,
       0.12803291, 0.12678831, 0.12626308, 0.12507224, 0.1248102 ,
       0.12383852, 0.121826  , 0.11985217, 0.11986669, 0.11762512,
       0.1181166 , 0.11759082, 0.11575512, 0.11410792, 0.11531784,
       0.1169539 , 0.11614721, 0.11519321, 0.11456495, 0.11471919,
       0.11496413, 0.11304017, 0.10994165, 0.11212726, 0.11287158,
       0.11276065, 0.10822126]

Gaufen_MEAN = [123.94924583,  92.58088583,  97.28130189,  90.31526596]
Gaufen_STD = [67.34487297, 62.8271046 , 60.5856767 , 60.3946299]

# %%
class DataAugmentation(torch.nn.Module):
    def __init__(self, mean, std):
        super().__init__()
        self.transform = torch.nn.Sequential(
            K.augmentation.RandomResizedCrop(size=(224,224), scale=(0.2,1.0)),
            K.augmentation.Normalize(mean=mean,std=std)
        )
    @torch.no_grad()
    def forward(self,x):
        # Check if the input is a dictionary and apply transform to the 'image' key
        if isinstance(x, dict) and 'image' in x:
            x['image'] = self.transform(x['image']).squeeze(0)
            return x
        else:
            x_out = self.transform(x).squeeze(0)
            return x_out

# %%
transform = DataAugmentation(mean=S1_MEAN,std=S1_STD)

def preprocess_s1(vh_path, vv_path):
    with rasterio.open(vh_path) as f1:
        vh = f1.read()
    with rasterio.open(vv_path) as f2:
        vv = f2.read()
    s1_img = np.concatenate((vh,vv),0).astype('float32')
    s1_img = torch.from_numpy(s1_img)
    s1_img = transform(s1_img).squeeze(0)
    return s1_img

# %%
import glob

C = 9

transform = DataAugmentation(mean=S2_MEAN,std=S2_STD)

def preprocess_s2(img_path):
    chs = []
    s2_files = glob.glob(f"{img_path}/*/*.png")
    for path in s2_files:
        with rasterio.open(path) as f:
            ch = f.read()
        chs.append(ch)
    s2_img = np.concatenate(chs, 0).astype("float32")
    s2_img = torch.from_numpy(s2_img)
    s2_img = transform(s2_img).squeeze(0)
    return s2_img

# %%
from torchgeo.datasets import FireRisk
import kornia as K
import numpy as np
import torch
import matplotlib.pyplot as plt

NAIP_transform = DataAugmentation(mean=NAIP_MEAN, std=NAIP_STD)

dataset_train = FireRisk(root='data', split='train', transforms=None, download=True, checksum=False)

print(dataset_train)
sample = dataset_train[9999]
print(sample.keys())
print(sample['image'].shape, sample['label'])

# Extract and prepare image data for plotting with Matplotlib
image_to_plot = sample['image'].permute(1, 2, 0).numpy().astype(np.uint8)

print(f"Type of image before plot: {type(image_to_plot)}")
print(f"Shape of image before plot: {image_to_plot.shape}")

plt.imshow(image_to_plot)
plt.title(f"Label: {sample['label'].item()}")
plt.axis('off')
plt.show()
# Out:
# FireRisk Dataset
#     type: NonGeoDataset
#     size: 70331
# dict_keys(['image', 'label'])
# torch.Size([3, 320, 320]) tensor(1)
# Type of image before plot: <class 'numpy.ndarray'>
# Shape of image before plot: (320, 320, 3)

# %% [markdown]
# ### Load the pre-trained weights of DOFA base model

# %%
from dofa_v1 import vit_base_patch16

check_point = torch.load('./checkpoints/DOFA_ViT_base_e100.pth')
vit_model = vit_base_patch16()
msg = vit_model.load_state_dict(check_point, strict=False)
# missing_keys=['fc_norm.weight', 'fc_norm.bias', 'head.weight', 'head.bias'], unexpected_keys=['mask_token', 'norm.weight', 'norm.bias', 'projector.weight', 'projector.bias']
vit_model = vit_model.cuda()

# %%
wavelengths = [3.75, 3.75]
out_feat = vit_model.forward_features(s1_img, wave_list=wavelengths)
out_logits = vit_model.forward(s1_img, wave_list=wavelengths)
print(out_feat.shape)
print(out_logits.shape)
# Out:
# torch.Size([1, 768])
# torch.Size([1, 45])

# %%
s2_img = preprocess_s2("data/s2/S2A_MSIL1C_20170528T050611_N0205_R076_T44NMM_20170528T050606")
fig, ax = plt.subplots(nrows=1, ncols=C, figsize=(10, 10))

for i,row in enumerate(ax):
    row.imshow(s2_img[i])
    row.axis("off")
s2_img = s2_img.view([1,C,224,224]).cuda()
# Out:
# /opt/miniconda3/lib/python3.11/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %% [markdown]
# Visualize the Sentinel-2 imagery

# %% [markdown]
# ### We use the same DOFA model to inference the Sentinel-2 image

# %%
wavelengths = [0.665, 0.56, 0.49, 0.705, 0.74, 0.783, 0.842, 1.61, 2.19]

out_feat = vit_model.forward_features(s2_img, wave_list=wavelengths)
out_logits = vit_model.forward(s2_img, wave_list=wavelengths)
print(out_feat.shape)
print(out_logits.shape)
# Out:
# torch.Size([1, 768])
# torch.Size([1, 45])

# %% [markdown]
# ### What if I only want to use a subset of Sentinel-2 data?

# %%
# Let's only keep the first 5 channels
wavelengths = [0.665, 0.56, 0.49, 0.705, 0.74]

out_feat = vit_model.forward_features(s2_img[:,:5,...], wave_list=wavelengths)
out_logits = vit_model.forward(s2_img[:,:5,...], wave_list=wavelengths)
print(out_feat.shape)
print(out_logits.shape)
# Out:
# torch.Size([1, 768])
# torch.Size([1, 45])

# %% [markdown]
# ### Usage for RGB optical data

# %%
C = 3

transform = DataAugmentation(mean=NAIP_MEAN, std=NAIP_STD)


def preprocess_rgb(img_path):
    with rasterio.open(img_path) as f:
        rgb_img = f.read().astype("float32")
    rgb_img = torch.from_numpy(rgb_img)
    rgb_img = transform(rgb_img).squeeze(0)
    return rgb_img

# %%
# Please install cv2 by "pip install opencv-python"
# or other lib for image reading

import cv2

rgb_path = 'data/naip/36861_49963.png'
naip_img = preprocess_rgb(rgb_path)

plt.imshow(cv2.cvtColor(cv2.imread(rgb_path), cv2.COLOR_BGR2RGB))
plt.axis("off")

naip_img = naip_img.view([1,C,224,224]).cuda()

# %%
wavelengths = [0.665, 0.56, 0.49]

out_feat = vit_model.forward_features(naip_img, wave_list=wavelengths)
out_logits = vit_model.forward(naip_img, wave_list=wavelengths)
print(out_feat.shape)
print(out_logits.shape)
# Out:
# torch.Size([1, 768])
# torch.Size([1, 45])

# %% [markdown]
# ### Coming soon: Usage for Hyperspectral data
